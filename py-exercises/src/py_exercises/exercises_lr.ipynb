# %%
import mermaid as mmd

from parsers.lr0 import LR0Parser
from parsers.example_grammars import GRAMMAR_3_20
from parsers.lr_graph import lr_parser_to_mermaid

# %%
p = LR0Parser()
p.add_rules(*GRAMMAR_3_20)
p.compute_states_and_edges()

# %%
fl = lr_parser_to_mermaid(p, title="grammar 3.20")
mmd.Mermaid(fl).to_png("static/grammar_3_20_graph.png")

# %% [markdown]
# <img src="static/grammar_3_20_graph.png" alt="Exercise 3.4 from book" width="600">
