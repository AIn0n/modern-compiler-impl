# %% [markdown]
# # Exercise 3.10
#
# Diagram the LR(1) states for the grammar of Exercise 3.7 (without left-factoring),
# and construct the LR(1) parsing table. Indicate clearly any conflicts.

# %%
exercise_3_7_grammar = [
    "S -> G $",
    "G -> P",
    "G -> P G",
    "P -> id : R",
    "R ->",
    "R -> id R",
]
